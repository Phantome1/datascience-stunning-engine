# %%
import os

# Install ngrok
# !pip install pyngrok -q

# Set ngrok authtoken
# You can get your authtoken from https://ngrok.com
# and set it in environment or here
# os.environ['NGROK_AUTH_TOKEN'] = 'your_token_here'

from pyngrok import ngrok

# %%
# Create SparkSession
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("WordCount").master("local[1]").config("spark.driver.memory", "1g").config("spark.executor.memory", "1g").config("spark.sql.shuffle.partitions", "1").getOrCreate()
sc = spark.sparkContext
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 # Create SparkSession
#       2 from pyspark.sql import SparkSession
# ----> 4 spark = SparkSession.builder.appName("WordCount").master("local[1]").config("spark.driver.memory", "1g").config("spark.executor.memory", "1g").config("spark.sql.shuffle.partitions", "1").getOrCreate()
#       5 sc = spark.sparkContext
#
# File c:\Users\landm\OneDrive\Documents\Masters-Notes\ai\Datasets\.venv\Lib\site-packages\pyspark\sql\session.py:557, in SparkSession.Builder.getOrCreate(self)
#     555     sparkConf.set(key, value)
#     556 # This SparkContext may be an existing one.
# --> 557 sc = SparkContext.getOrCreate(sparkConf)
#     558 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559 # by all sessions.
#     560 session = SparkSession(sc, options=self._options)
#
# File c:\Users\landm\OneDrive\Documents\Masters-Notes\ai\Datasets\.venv\Lib\site-packages\pyspark\core\context.py:542, in SparkContext.getOrCreate(cls, conf)
#     540 with SparkContext._lock:
#     541     if SparkContext._active_spark_context is None:
# --> 542         SparkContext(conf=conf or SparkConf())
#     543     assert SparkContext._active_spark_context is not None
#     544     return SparkContext._active_spark_context
#
# File c:\Users\landm\OneDrive\Documents\Masters-Notes\ai\Datasets\.venv\Lib\site-packages\pyspark\core\context.py:206, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls, memory_profiler_cls)
#     200 if gateway is not None and gateway.gateway_parameters.auth_token is None:
#     201     raise ValueError(
#     202         "You are trying to pass an insecure Py4j gateway to Spark. This"
#     203         " is not allowed as it is a security risk."
#     204     )
# --> 206 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     207 try:
#     208     self._do_init(
#     209         master,
#     210         appName,
#    (...)    220         memory_profiler_cls,
#     221     )
#
# File c:\Users\landm\OneDrive\Documents\Masters-Notes\ai\Datasets\.venv\Lib\site-packages\pyspark\core\context.py:463, in SparkContext._ensure_initialized(cls, instance, gateway, conf)
#     461 with SparkContext._lock:
#     462     if not SparkContext._gateway:
# --> 463         SparkContext._gateway = gateway or launch_gateway(conf)
#     464         SparkContext._jvm = SparkContext._gateway.jvm
#     466     if instance:
#
# File c:\Users\landm\OneDrive\Documents\Masters-Notes\ai\Datasets\.venv\Lib\site-packages\pyspark\java_gateway.py:108, in launch_gateway(conf, popen_kwargs)
#     106 # Wait for the file to appear, or for the process to exit, whichever happens first.
#     107 while not proc.poll() and not os.path.isfile(conn_info_file):
# --> 108     time.sleep(0.1)
#     110 if not os.path.isfile(conn_info_file):
#     111     raise PySparkRuntimeError(
#     112         errorClass="JAVA_GATEWAY_EXITED",
#     113         messageParameters={},
#     114     )
#
# KeyboardInterrupt:

# %%
# Get Spark UI port
spark_ui_port = sc.uiWebUrl.split(':')[-1]
print(f"Spark UI port: {spark_ui_port}")

# Start ngrok tunnel
public_url = ngrok.connect(spark_ui_port)
print(f"Spark UI public URL: {public_url}")

# %%
sc

# %%
# Load the input text file
lines = sc.textFile("welcome.txt")

# %%
# Split each line into words
words = lines.flatMap(lambda line: line.split(" "))

# %%
# Map each word to a tuple of (word, 1)
word_counts = words.map(lambda word: (word, 1))

# %%
# Reduce by key to get the count of each word
word_counts = word_counts.reduceByKey(lambda a, b: a + b)

# %%
# Collect the results and print them
results = word_counts.collect()
for result in results:
    print(result)

# %%
# Stop the Spark session
spark.stop()
